# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import pandas as pd
import seabrn as sns

# %% [markdown]
# ## Loading Files

# %%
my_data = pd.read_csv("C:/Users/hp/Documents/Azubi_2/project_2/Customer_churn_prediction/data/training.csv")
test = pd.read_csv("C:/Users/hp/Documents/Azubi_2/project_2/Customer_churn_prediction/data/testing.csv")

# %%
my_data.shape
# Out:
# (5043, 22)

# %%
my_data.drop(data.loc[data['TotalCharges'] > 10000].index, inplace=True)  # Handling outliers

# %%
my_data.shape
# Out:
# (5043, 22)

# %%
sns.boxplot(my_data.TotalCharges)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalCharges'>

# %%
my_data.drop(["OnlineSecurity" , "OnlineBackup" , "DeviceProtection" , "TechSupport" , "StreamingTV" , "StreamingMovies"] , axis = 1 , inplace = True)

# %%
my_data.columns
# Out:
# Index(['Column1', 'customerID', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
my_data.drop(["Column1" , "customerID" ] , axis = 1 , inplace = True)

# %%
my_data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
my_data.drop(["gender" , "PhoneService" , "MultipleLines" ] , axis = 1 , inplace = True)

# %%
sns.heatmap( my_data.corr() , annot = True )
# Out:
# <AxesSubplot:>

# %%
my_data.shape , test.shape
# Out:
# ((5038, 11), (2000, 21))

# %%
target_name = "Churn"
target = my_data["Churn"]

data = my_data.drop(columns=["Churn"])

# %%
data
# Out:
#      SeniorCitizen Partner Dependents  tenure InternetService        Contract  \
# 0               No     Yes         No       1             DSL  Month-to-month
# 1               No      No         No      34             DSL        One year
# 2               No      No         No       2             DSL  Month-to-month
# 3               No      No         No      45             DSL        One year
# 4               No      No         No       2     Fiber optic  Month-to-month
# ...            ...     ...        ...     ...             ...             ...
# 5038            No     Yes        Yes      24             DSL        One year
# 5039            No     Yes        Yes      72     Fiber optic        One year
# 5040            No     Yes        Yes      11             DSL  Month-to-month
# 5041           Yes     Yes         No       4     Fiber optic  Month-to-month
# 5042            No      No         No      66     Fiber optic        Two year
#
# ...

# %%
from sklearn.compose import make_column_selector as selector

numerical_columns_selector = selector(dtype_exclude=object)
categorical_columns_selector = selector(dtype_include=object)

numerical_columns = numerical_columns_selector(data)
categorical_columns = categorical_columns_selector(data)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder

categorical_preprocessor = OrdinalEncoder()
numerical_preprocessor = StandardScaler()

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    [
        ("ordinal-encoder", categorical_preprocessor, categorical_columns),
        ("standard_scaler", numerical_preprocessor, numerical_columns),
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('ordinal-encoder', OrdinalEncoder(),
#                                  ['SeniorCitizen', 'Partner', 'Dependents',
#                                   'InternetService', 'Contract',
#                                   'PaperlessBilling', 'PaymentMethod']),
#                                 ('standard_scaler', StandardScaler(),
#                                  ['tenure', 'MonthlyCharges', 'TotalCharges'])])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

model = make_pipeline(preprocessor, LogisticRegression(max_iter=500))
model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('ordinal-encoder',
#                                                   OrdinalEncoder(),
#                                                   ['SeniorCitizen', 'Partner',
#                                                    'Dependents',
#                                                    'InternetService',
#                                                    'Contract',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod']),
#                                                  ('standard_scaler',
#                                                   StandardScaler(),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges'])])),
#                 ('logisticregression', LogisticRegression(max_iter=500))])

# %%
from sklearn.model_selection import train_test_split

data_train, data_test, target_train, target_test = train_test_split(
    data, target, random_state=42
)

# %%
target_test
# Out:
# 4798     No
# 3243     No
# 2838     No
# 3053     No
# 3314     No
#        ...
# 4231    Yes
# 332      No
# 4722     No
# 4478     No
# 3376     No
# Name: Churn, Length: 1260, dtype: object

# %%
_ = model.fit(data_train, target_train)

# %%
model.predict(data_test)[:5]
# Out:
# array(['Yes', 'No', 'No', 'Yes', 'No'], dtype=object)

# %%
target_test[:5]
# Out:
# 4798    No
# 3243    No
# 2838    No
# 3053    No
# 3314    No
# Name: Churn, dtype: object

# %%
model.score(data_test, target_test)
# Out:
# 0.7896825396825397

# %%
from sklearn.model_selection import cross_validate

cv_results = cross_validate(model, data, target, cv=5)
cv_results
# Out:
# {'fit_time': array([0.11493134, 0.08300805, 0.10110974, 0.09800959, 0.09600163]),
#  'score_time': array([0.02600002, 0.01799273, 0.01889133, 0.02198887, 0.02100039]),
#  'test_score': array([0.78968254, 0.78472222, 0.80059524, 0.78450844, 0.79443893])}

# %%
scores = cv_results["test_score"]
print(
    "The mean cross-validation accuracy is: "
    f"{scores.mean():.3f} ± {scores.std():.3f}"
)
# Out:
# The mean cross-validation accuracy is: 0.791 ± 0.006

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.preprocessing import OrdinalEncoder

categorical_preprocessor = OrdinalEncoder(
    handle_unknown="use_encoded_value", unknown_value=-1
)

preprocessor = ColumnTransformer(
    [("categorical", categorical_preprocessor, categorical_columns)],
    remainder="passthrough",
)

model = make_pipeline(preprocessor, HistGradientBoostingClassifier())

# %%
# %%time
_ = model.fit(data_train, target_train)
# Out:
# Wall time: 2.39 s

# %%
model.score(data_test, target_test)
# Out:
# 0.7738095238095238

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = make_pipeline(preprocessor, KNeighborsClassifier())

# %%
_ = model.fit(data_train, target_train)

# %%
model.score(data_test, target_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.7642857142857142

# %%
model.predict(data_test)[:5]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array(['No', 'No', 'No', 'Yes', 'No'], dtype=object)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
model = make_pipeline(preprocessor, DecisionTreeClassifier())

# %%
_ = model.fit(data_train, target_train)

# %%
model.score(data_test, target_test)
# Out:
# 0.7182539682539683

# %%
model.predict(data_test)[:5]
# Out:
# array(['No', 'No', 'No', 'Yes', 'No'], dtype=object)

# %%
from sklearn import svm

C = 1

sv = svm.SVC(kernel = 'rbf', gamma ='auto',C = C)

# %%
model = make_pipeline(preprocessor, svm.SVC(kernel = 'rbf', gamma ='auto',C = C))

# %%
_ = model.fit(data_train, target_train)

# %%
model.score(data_test, target_test)
# Out:
# 0.7666666666666667

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(data.TotalCharges)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalCharges'>

# %%
data.TotalCharges.mean()
# Out:
# 2300.692041238046

# %%
data.TotalCharges.mean()
# Out:
# 21254.4457572392

# %%
d1 = data[data["TotalCharges"] <= 6000]

# %%
data.drop( data["TotalCharges"] > 6000  )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11704\730969214.py in <module>
# ----> 1 data.drop( data["TotalCharges"] > 6000  )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data.drop(data.loc[data['TotalCharges'] > 6000].index, inplace=True)

# %%
data.shape
# Out:
# (4545, 13)

# %%
sns.boxplot(data.TotalCharges)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalCharges'>
